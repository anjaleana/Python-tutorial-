# %% [markdown]
# ### Accessing Character of String

# %% [markdown]
# ![unnamed.png](attachment:unnamed.png)

# %%
str = input("Enter the String:")
#let's print the initial String

print(str)

# want to access the character of String

#print(str[0])

#print(str[2])

#print(str[-2])

#print(str[2:-2])

str[2] = 'p'

print(str)
# Out:
# Enter the String:String
# String
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-ada4f048fe87> in <module>
#      14 #print(str[2:-2])
#      15
# ---> 16 str[2] = 'p'
#      17
#      18 print(str)
#
# TypeError: 'str' object does not support item assignment
